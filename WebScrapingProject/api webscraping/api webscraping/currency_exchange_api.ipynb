# %%
import requests
import pandas as pd

# %%
url="https://api.frankfurter.app/latest?from=USD&to=INR,EUR,GBP,JPY"
response = requests.get(url)

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.json())
# Out:
# {'amount': 1.0, 'base': 'USD', 'date': '2026-07-02', 'rates': {'EUR': 0.87727, 'GBP': 0.75151, 'INR': 95.39, 'JPY': 161.58}}

# %%
data= response.json()

# %%
for item in data:
    print(item, ":", data[item])
# Out:
# amount : 1.0
# base : USD
# date : 2026-07-02
# rates : {'EUR': 0.87727, 'GBP': 0.75151, 'INR': 95.39, 'JPY': 161.58}

# %%
df =pd.DataFrame(data)
df
# Out:
#      amount base        date      rates
# EUR     1.0  USD  2026-07-02    0.87727
# GBP     1.0  USD  2026-07-02    0.75151
# INR     1.0  USD  2026-07-02   95.39000
# JPY     1.0  USD  2026-07-02  161.58000
