# %%
import requests
import pandas as pd

# %%
url ="https://api.tvmaze.com/shows"
response=requests.get(url)

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.json())
# Out:
# [{'id': 1, 'url': 'https://www.tvmaze.com/shows/1/under-the-dome', 'name': 'Under the Dome', 'type': 'Scripted', 'language': 'English', 'genres': ['Drama', 'Science-Fiction', 'Thriller'], 'status': 'Ended', 'runtime': 60, 'averageRuntime': 60, 'premiered': '2013-06-24', 'ended': '2015-09-10', 'officialSite': 'http://www.cbs.com/shows/under-the-dome/', 'schedule': {'time': '22:00', 'days': ['Thursday']}, 'rating': {'average': 6.6}, 'weight': 99, 'network': {'id': 2, 'name': 'CBS', 'country': {'name': 'United States', 'code': 'US', 'timezone': 'America/New_York'}, 'officialSite': 'https://www.cbs.com/'}, 'webChannel': None, 'dvdCountry': None, 'externals': {'tvrage': 25988, 'thetvdb': 264492, 'imdb': 'tt1553656'}, 'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/610/1525272.jpg', 'original': 'https://static.tvmaze.com/uploads/images/original_untouched/610/1525272.jpg'}, 'summary': "<p><b>Under the Dome</b> is the story of a small town that is suddenly and i
# ...

# %%
data= response.json()

# %%
for item in data:
    print(item['id'])
    print(item['name'])   
    print(item['url'])  
    print(item['type'])    
    print(item['language'])   
    print(item['genres'])   
    print(item['status'])
    print(item['runtime'])
    print(item['premiered'])
    print(item['rating'])
    print(item['image'])
    print(item['summary'])
    print(item['_links'])
# Out:
# 1
# Under the Dome
# https://www.tvmaze.com/shows/1/under-the-dome
# Scripted
# English
# ['Drama', 'Science-Fiction', 'Thriller']
# Ended
# 60
# 2013-06-24
# {'average': 6.6}
# {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/610/1525272.jpg', 'original': 'https://static.tvmaze.com/uploads/images/original_untouched/610/1525272.jpg'}
# <p><b>Under the Dome</b> is the story of a small town that is suddenly and inexplicably sealed off from the rest of the world by an enormous transparent dome. The town's inhabitants must deal with surviving the post-apocalyptic conditions while searching for answers about the dome, where it came from and if and when it will go away.</p>
# {'self': {'href': 'https://api.tvmaze.com/shows/1'}, 'previousepisode': {'href': 'https://api.tvmaze.com/episodes/185054', 'name': 'The Enemy Within'}}
# 2
# Person of Interest
# https://www.tvmaze.com/shows/2/person-of-interest
# Scripted
# English
# ['Action', 'Crime', 'Science-Fiction']
# Ended
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#       id                                                url  \
# 0      1      https://www.tvmaze.com/shows/1/under-the-dome
# 1      2  https://www.tvmaze.com/shows/2/person-of-interest
# 2      3              https://www.tvmaze.com/shows/3/bitten
# 3      4               https://www.tvmaze.com/shows/4/arrow
# 4      5      https://www.tvmaze.com/shows/5/true-detective
# ..   ...                                                ...
# 235  245  https://www.tvmaze.com/shows/245/town-of-the-l...
# 236  246       https://www.tvmaze.com/shows/246/long-shadow
# 237  247  https://www.tvmaze.com/shows/247/the-colbert-r...
# 238  248  https://www.tvmaze.com/shows/248/transporter-t...
# 239  249  https://www.tvmaze.com/shows/249/the-daily-sho...
#
#                                 name         type language  \
# 0                     Under the Dome     Scripted  English
# 1                 Person of Interest     Scripted  English
# 2                             Bitten     Scripted  English
# ...
