# %% [markdown]
# %%html
#
# <style>
# .header{
#     text-align:center;
#     padding:25px;
#     border-radius:20px;
#     background:linear-gradient(135deg,#6C63FF,#00B4DB);
#     color:white;
#     animation:fadeIn 2s ease-in-out;
#     box-shadow:0 10px 25px rgba(0,0,0,.25);
#     font-family:Arial, sans-serif;
# }
#
# .header h1{
#     font-size:40px;
#     margin-bottom:10px;
#     animation:glow 2s infinite alternate;
# }
#
# .header h2{
#     font-size:20px;
#     font-weight:normal;
#     margin-bottom:18px;
# }
#
# .info{
#     margin-top:15px;
#     display:inline-block;
#     text-align:left;
#     background:rgba(255,255,255,.15);
#     padding:18px 30px;
#     border-radius:15px;
#     line-height:1.8;
#     font-size:16px;
# }
#
# @keyframes fadeIn{
#     from{
#         opacity:0;
#         transform:translateY(-30px);
#     }
#     to{
#         opacity:1;
#         transform:translateY(0);
#     }
# }
#
# @keyframes glow{
#     from{
#         text-shadow:0 0 8px white;
#     }
#     to{
#         text-shadow:0 0 20px #FFD700;
#     }
# }
# </style>
#
# <div class="header">
#
# <h1>📚 Static Web Scraping Using Python & BeautifulSoup</h1>
#
# <h2>Extracting Goodreads Quotes Data from a Static Website</h2>
#
# <div class="info">
#
# <b>👩‍💻 Prepared By:</b> Sunaina Saini <br>
# <b>🎓 Course:</b> B.Tech – Artificial Intelligence & Machine Learning (AIML) <br>
# <b>🏢 Internship:</b> AIML Bootcamp – CodroidHub Pvt. Ltd. <br>
# <b>🌐 Website:</b> Goodreads Quotes (Static Website) <br>
# <b>🕸️ Scraping Type:</b> Static Web Scraping <br>
# <b>💻 Language:</b> Python <br>
# <b>📚 Libraries:</b> Requests, BeautifulSoup4, Pandas <br>
# <b>📂 Output:</b> CSV Dataset of Quotes, Authors & Tags <br>
# <b>📅 Date:</b> July 2026
#
# </div>
#
# </div>

# %% [markdown]
# # Import Required Libraries
#
# Import all the libraries needed for web scraping, data handling, and exporting the scraped data.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# # Define the Target Website
#
# Specify the URL of the webpage that will be scraped.

# %%
url = 'https://www.goodreads.com/quotes'

# %% [markdown]
# # Add Browser Headers
#
#
# Provide request headers so the website recognizes the request as coming from a real web browser.

# %%
HEADERS = ({'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'

})

# %% [markdown]
# # Send HTTP Request
#
# Send a GET request to the website and retrieve its HTML content.

# %%
response = requests.get(url,headers = HEADERS)

# %% [markdown]
# # Check the Response
#
#
# Verify whether the request was successful by checking the HTTP status code.

# %%
print(response.status_code)
# Out:
# 200

# %% [markdown]
# # Inspect Response Content
#
#
# Check the type of the downloaded content.

# %%
type(response.content)
# Out:
# bytes

# %% [markdown]
# # Parse the HTML
#
# Convert the HTML into a BeautifulSoup object for easier navigation.

# %%
soup = BeautifulSoup(response.content,"html.parser")

# %% [markdown]
# # Preview the HTML Structure
#
#
# Display the parsed HTML structure for understanding the webpage layout.

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="desktop withSiteHeaderTopFullImage">
# <head>
# <title>Popular Quotes</title>
# <meta content="Popular quotes from Goodreads members. Oscar Wilde: ‘Be yourself; everyone else is already taken.’, Marilyn Monroe: ‘I'm selfish, impatient and a little ..." name="description"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://www.goodreads.com/quotes" rel="canonical"/>
# <!-- * Copied from https://info.analytics.a2z.com/#/docs/data_collection/csa/onboard */ -->
# <script>
#   //<![CDATA[
#     !function(){function n(n,t){var r=i(n);return t&&(r=r("instance",t)),r}var r=[],c=0,i=function(t){return function(){var n=c++;return r.push([t,[].slice.call(arguments,0),n,{time:Date.now()}]),i(n)}};n._s=r,this.csa=n}();
#
#     if (window.csa) {
#       window.csa("Config", {
#         "Application": "GoodreadsMonolith",
#         "Events.SushiEndpoint": "https://unagi.amazon.com/1/events/com.amazon.csm.csa.prod",
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="desktop withSiteHeaderTopFullImage">
#  <head>
#   <title>
#    Popular Quotes
#   </title>
#   <meta content="Popular quotes from Goodreads members. Oscar Wilde: ‘Be yourself; everyone else is already taken.’, Marilyn Monroe: ‘I'm selfish, impatient and a little ..." name="description"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="https://www.goodreads.com/quotes" rel="canonical"/>
#   <!-- * Copied from https://info.analytics.a2z.com/#/docs/data_collection/csa/onboard */ -->
#   <script>
#    //<![CDATA[
#     !function(){function n(n,t){var r=i(n);return t&&(r=r("instance",t)),r}var r=[],c=0,i=function(t){return function(){var n=c++;return r.push([t,[].slice.call(arguments,0),n,{time:Date.now()}]),i(n)}};n._s=r,this.csa=n}();
#
#     if (window.csa) {
#       window.csa("Config", {
#         "Application": "GoodreadsMonolith",
# ...

# %% [markdown]
# # Locate Quote Containers
#
#
# Find all quote cards using their HTML class.

# %%
book_data = soup.find_all( "div",class_="quote")
#book_data = soup.find_all( "div",class_="quoteText")
len(book_data)
# Out:
# 30

# %% [markdown]
# # Verify Scraped Elements
#
#
# Display the first quote container to understand its HTML structure.

# %%
print(soup.find("div",class_="quote"))
# Out:
# <div class="quote">
# <div class="quoteDetails">
# <a class="leftAlignedImage quoteAvatar" href="/author/show/3565.Oscar_Wilde">
# <img alt="Oscar Wilde" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/authors/1673611182i/3565._UX200_CR0,15,200,200_.jpg"/>
# </a>
# <div class="quoteText">
#       “Be yourself; everyone else is already taken.”
#     <br/>
#   ―
#   <span class="authorOrTitle">
#     Oscar Wilde
#   </span>
# </div>
# <div class="quoteFooter">
# <div class="right">
# <a class="smallText" href="/quotes/19884-be-yourself-everyone-else-is-already-taken" title="View this quote">178537 likes</a>
# </div>
# </div>
# </div>
# <div class="action">
# <a class="gr-button gr-button--small" href="/user/new" rel="nofollow">Like</a>
# </div>
# </div>

# %% [markdown]
# # Display All Quote Containers
#
#
# Print all the quote elements extracted from the webpage.

# %%
print(book_data)
# Out:
# [<div class="quote">
# <div class="quoteDetails">
# <a class="leftAlignedImage quoteAvatar" href="/author/show/3565.Oscar_Wilde">
# <img alt="Oscar Wilde" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/authors/1673611182i/3565._UX200_CR0,15,200,200_.jpg"/>
# </a>
# <div class="quoteText">
#       “Be yourself; everyone else is already taken.”
#     <br/>
#   ―
#   <span class="authorOrTitle">
#     Oscar Wilde
#   </span>
# </div>
# <div class="quoteFooter">
# <div class="right">
# <a class="smallText" href="/quotes/19884-be-yourself-everyone-else-is-already-taken" title="View this quote">178537 likes</a>
# </div>
# </div>
# </div>
# <div class="action">
# <a class="gr-button gr-button--small" href="/user/new" rel="nofollow">Like</a>
# </div>
# </div>, <div class="quote">
# <div class="quoteDetails">
# <a class="leftAlignedImage quoteAvatar" href="https://images.gr-assets.com/quotes/1511992603p8/8630.jpg">
# ...

# %%
book_data
# Out:
# [<div class="quote">
#  <div class="quoteDetails">
#  <a class="leftAlignedImage quoteAvatar" href="/author/show/3565.Oscar_Wilde">
#  <img alt="Oscar Wilde" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/authors/1673611182i/3565._UX200_CR0,15,200,200_.jpg"/>
#  </a>
#  <div class="quoteText">
#        “Be yourself; everyone else is already taken.”
#      <br/>
#    ―
#    <span class="authorOrTitle">
#      Oscar Wilde
#    </span>
#  </div>
#  <div class="quoteFooter">
#  <div class="right">
#  <a class="smallText" href="/quotes/19884-be-yourself-everyone-else-is-already-taken" title="View this quote">178537 likes</a>
#  </div>
#  </div>
#  </div>
#  <div class="action">
#  <a class="gr-button gr-button--small" href="/user/new" rel="nofollow">Like</a>
#  </div>
#  </div>,
#  <div class="quote">
#  <div class="quoteDetails">
#  <a class="leftAlignedImage quoteAvatar" href="https://images.gr-assets.com/quotes/1511992603p8/8630.jpg">
# ...

# %% [markdown]
# # Count Total Quotes
#
#
# Determine the total number of quotes available on the page.

# %%
print(len(book_data))
# Out:
# 30

# %% [markdown]
# # Extract Required Information
#
#
# Loop through each quote card and extract useful information such as:
#
# Quote,
# Author,
# Tags

# %%
# 1. Create a separate list for results
all_books = []

for book in book_data:
    title = book.find("span", class_="authorOrTitle")
    quote = book.find("div", class_="quoteText")
    likes = book.find("a", class_="smallText")

    # 2. Append to the new list instead
    all_books.append({
        "title": title.text.strip() if title else "N/A",
        "quote": quote.text.strip() if quote else "N/A",
        "likes": likes.text.strip() if likes else "N/A",
    })

# %% [markdown]
# # Create a DataFrame
#
#
# Convert the extracted data into a Pandas DataFrame for easier analysis.

# %%
df = pd.DataFrame(all_books)
df
# Out:
#                       title  \
# 0               Oscar Wilde
# 1            Marilyn Monroe
# 2               Frank Zappa
# 3           Albert Einstein
# 4     Marcus Tullius Cicero
# 5         Bernard M. Baruch
# 6         William W. Purkey
# 7                 Dr. Seuss
# 8                  Mae West
# 9            Mahatma Gandhi
# 10             Robert Frost
# 11            J.K. Rowling,
# 12             Albert Camus
# 13               Mark Twain
# 14             Maya Angelou
# 15              C.S. Lewis,
# 16              Oscar Wilde
# 17           Elbert Hubbard
# 18              Oscar Wilde
# 19  Martin Luther King Jr.,
# 20           Mahatma Gandhi
# 21         Stephen Chbosky,
# 22     Friedrich Nietzsche,
# 23             Oscar Wilde,
# 24      Ralph Waldo Emerson
# 25               Steve Jobs
# 26      Narcotics Anonymous
# 27              Andre Gide,
# 28           Marilyn Monroe
# 29    H. Jackson Brown Jr.,
#
# ...

# %% [markdown]
# # Preview the Dataset
#
#
# Display the first few rows of the scraped dataset.

# %%
df.head()
# Out:
#                    title                                              quote  \
# 0            Oscar Wilde  “Be yourself; everyone else is already taken.”...
# 1         Marilyn Monroe  “I'm selfish, impatient and a little insecure....
# 2            Frank Zappa  “So many books, so little time.”\n    \n  ―\n ...
# 3        Albert Einstein  “Two things are infinite: the universe and hum...
# 4  Marcus Tullius Cicero  “A room without books is like a body without a...
#
#           likes
# 0  178537 likes
# 1  165858 likes
# 2  152626 likes
# 3  149048 likes
# 4  136075 likes

# %% [markdown]
# # Export to CSV
#
#
# Save the scraped data as a CSV file for future use.

# %%
df.to_csv("goodreads_scraped_books.csv", index=False)
print("CSV file created successfully!")
# Out:
# CSV file created successfully!
