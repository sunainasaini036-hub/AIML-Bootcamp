# %% [markdown]
# %%html
#
# <style>
# .header{
#     text-align:center;
#     padding:25px;
#     border-radius:20px;
#     background:linear-gradient(135deg,#4CAF50,#2196F3);
#     color:white;
#     animation:fadeIn 2s ease-in-out;
#     box-shadow:0 10px 25px rgba(0,0,0,.25);
#     font-family:Arial, sans-serif;
# }
#
# .header h1{
#     font-size:40px;
#     margin-bottom:10px;
#     animation:glow 2s infinite alternate;
# }
#
# .header h2{
#     font-size:20px;
#     font-weight:normal;
#     margin-bottom:18px;
# }
#
# .info{
#     margin-top:15px;
#     display:inline-block;
#     text-align:left;
#     background:rgba(255,255,255,.15);
#     padding:18px 30px;
#     border-radius:15px;
#     line-height:1.8;
#     font-size:16px;
# }
#
# @keyframes fadeIn{
#     from{
#         opacity:0;
#         transform:translateY(-30px);
#     }
#     to{
#         opacity:1;
#         transform:translateY(0);
#     }
# }
#
# @keyframes glow{
#     from{
#         text-shadow:0 0 8px white;
#     }
#     to{
#         text-shadow:0 0 20px #FFD700;
#     }
# }
# </style>
#
# <div class="header">
#
# <h1>🌍 World Population Explorer Using Python</h1>
#
# <h2>Analyzing and Visualizing Global Population Data</h2>
#
# <div class="info">
#
# <b>👩‍💻 Prepared By:</b> Sunaina Saini <br>
# <b>🎓 Course:</b> B.Tech – Artificial Intelligence & Machine Learning (AIML) <br>
# <b>🏢 Internship:</b> AIML Bootcamp – CodroidHub Pvt. Ltd. <br>
# <b>🌐 Dataset:</b> World Population Dataset <br>
# <b>📊 Project Type:</b> Exploratory Data Analysis (EDA) <br>
# <b>💻 Language:</b> Python <br>
# <b>📚 Libraries:</b> Pandas, NumPy, Matplotlib <br>
# <b>📂 Output:</b> Population Analysis, Insights & Visualizations <br>
# <b>📅 Date:</b> July 2026
#
# </div>
#
# </div>

# %% [markdown]
# # Import Required Libraries
#
# Import all the libraries needed for web scraping, data handling, and exporting the scraped data.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Define the Target Website
#
# Specify the URL of the webpage that will be scraped.

# %%
url="https://www.worldometers.info/world-population/population-by-country/"
response = requests.get(url)

# %% [markdown]
# # Add Browser Headers
#
#
# Provide request headers so the website recognizes the request as coming from a real web browser.

# %%
headers={
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# %% [markdown]
# # Send HTTP Request
#
# Send a GET request to the website and retrieve its HTML content.

# %%
response = requests.get(url,headers = HEADERS)

# %% [markdown]
# # Check the Response
#
#
# Verify whether the request was successful by checking the HTTP status code.

# %%
print(response.status_code)
# Out:
# 200

# %% [markdown]
# # Inspect Response Content
#
#
# Check the type of the downloaded content.

# %%
type(response.content)
# Out:
# <!DOCTYPE html><html lang="en" dir="ltr" data-astro-transition-scope="astro-s7reefwf-2"> <head><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width, initial-scale=1"><title>Population by Country (2026) - Worldometer</title><!-- <I18nTags /> --><script async src="https://www.googletagmanager.com/gtag/js?id=G-ZDP3BFSX60"></script> <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag() {
#     // eslint-disable-next-line prefer-rest-params
#     dataLayer.push(arguments);
#   }
#   gtag("js", new Date());
#   gtag("config", "G-ZDP3BFSX60", {
#     page_lang: document.documentElement.lang,
#   });
# ...

# %% [markdown]
# # Parse the HTML
#
# Convert the HTML into a BeautifulSoup object for easier navigation.

# %%
soup = BeautifulSoup(response.content,"html.parser")

# %% [markdown]
# # Preview the HTML Structure
#
#
# Display the parsed HTML structure for understanding the webpage layout.

# %%
soup

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-astro-transition-scope="astro-s7reefwf-2" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Population by Country (2026) - Worldometer
#   </title>
#   <!-- <I18nTags /> -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-ZDP3BFSX60">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag() {
#     // eslint-disable-next-line prefer-rest-params
#     dataLayer.push(arguments);
#   }
#   gtag("js", new Date());
#   gtag("config", "G-ZDP3BFSX60", {
#     page_lang: document.documentElement.lang,
#   });
#   </script>
#   <script crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-3701697624350410">
#   </script>
# ...

# %% [markdown]
# # Locate Quote Containers
#
#
# Find all quote cards using their HTML class.

# %%
population= soup.find_all("div", class_ = 'datatable-wrapper datatable-loading no-footer sortable searchable fixed-columns')
population
#<td data-testid-cell="ticker" class="[&_.symbol]:tw-text-md yf-1hgjbtd lpin shad" style="--_depth: false;">…</td>
# Out:
# []

# %% [markdown]
# # Display All Quote Containers
#
#
# Print all the quote elements extracted from the webpage.

# %%
print(population)

# %% [markdown]
# # Count Total Quotes
#
#
# Determine the total number of quotes available on the page.

# %%
print(len(population))

# %% [markdown]
# ##   Extract population Data
#
#
# Extract the required population information from the HTML elements and store it in Python lists for further processing.

# %%
data=[]

# %%
rows= soup.find_all("tr")
for row in rows:
    cols= row.find_all("td")
    data.append([col.get_text(strip=True)for col in cols])

# %%
data
# Out:
# [[],
#  ['1',
#   'India',
#   '1,476,625,576',
#   '0.87%',
#   '12,760,051',
#   '497',
#   '2,973,190',
#   'â\x88\x92440,456',
#   '1.93',
#   '29.2',
#   '37.6%',
#   '17.79%'],
#  ['2',
#   'China',
#   '1,412,914,089',
#   'â\x88\x920.22%',
#   'â\x88\x923,182,005',
#   '150',
#   '9,388,211',
#   'â\x88\x92232,107',
#   '1.03',
#   '40.6',
#   '68.7%',
#   '17.02%'],
#  ['3',
#   'United States',
#   '349,035,494',
#   '0.51%',
#   '1,759,687',
#   '38',
#   '9,147,420',
#   '1,177,848',
#   '1.63',
#   '38.7',
#   '83.1%',
#   '4.20%'],
#  ['4',
#   'Indonesia',
#   '287,886,782',
#   '0.76%',
#   '2,165,546',
#   '159',
#   '1,811,570',
#   'â\x88\x9239,472',
#   '2.08',
#   '30.7',
#   '60.3%',
#   '3.47%'],
#  ['5',
#   'Pakistan',
#   '259,299,791',
#   '1.6%',
#   '4,080,237',
#   '336',
#   '770,880',
#   'â\x88\x921,144,738',
#   '3.44',
#   '20.8',
#   '34.7%',
#   '3.12%'],
#  ['6',
#   'Nigeria',
#   '242,431,832',
#   '2.06%',
#   '4,904,050',
#   '266',
# ...

# %% [markdown]
# ## Create DataFrame
#
#
# Combine the extracted lists into a structured Pandas DataFrame.

# %%
df=pd.DataFrame(data)
df
# Out:
#       0                 1              2         3             4      5   \
# 0    NaN               NaN            NaN       NaN           NaN    NaN
# 1      1             India  1,476,625,576     0.87%    12,760,051    497
# 2      2             China  1,412,914,089  â0.22%  â3,182,005    150
# 3      3     United States    349,035,494     0.51%     1,759,687     38
# 4      4         Indonesia    287,886,782     0.76%     2,165,546    159
# ..   ...               ...            ...       ...           ...    ...
# 230  230        Montserrat          4,328  â0.71%         â31     43
# 231  231  Falkland Islands          3,465  â0.12%          â4      0
# 232  232           Tokelau          2,691     3.18%            83    269
# 233  233              Niue          1,822     0.05%             1      7
# 234  234          Holy See            506        1%             5  1,265
#
#             6           7     8     9      10          11
# ...

# %% [markdown]
# ##  Data cleaning

# %%
df.columns=[
    "Rank",
    "Country",
    "Population",
    "Yearly Change",
    "Net Change",
    "Density",
    "Land Area",
    "Migrants",
    "Fertility Rate",
    "Median Age",
    "Urban Population",
    "world share"
]

# %%
df=df.drop(index=0).reset_index(drop=True)
df
# Out:
#     Rank           Country     Population Yearly Change    Net Change Density  \
# 0      1             India  1,476,625,576         0.87%    12,760,051     497
# 1      2             China  1,412,914,089      â0.22%  â3,182,005     150
# 2      3     United States    349,035,494         0.51%     1,759,687      38
# 3      4         Indonesia    287,886,782         0.76%     2,165,546     159
# 4      5          Pakistan    259,299,791          1.6%     4,080,237     336
# ..   ...               ...            ...           ...           ...     ...
# 229  230        Montserrat          4,328      â0.71%         â31      43
# 230  231  Falkland Islands          3,465      â0.12%          â4       0
# 231  232           Tokelau          2,691         3.18%            83     269
# 232  233              Niue          1,822         0.05%             1       7
# 233  234          Holy See            506            1%             5   1,265
#
# ...

# %% [markdown]
# ## Export Dataset
#
#
# Save the cleaned dataset for future use.

# %%
df.to_csv("Population_growth_data.csv",index=False)
