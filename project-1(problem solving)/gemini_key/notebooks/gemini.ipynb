# %%
import google.generativeai as genai
print(genai.__version__)
# Out:
# 0.8.6

# %%
genai.configure(api_key ="GEMINI_API_KEY")

for model in genai.list_models():
  if "generateContent" in model.supported_generation_methods:
   print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-omni-flash-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025

# %%
import os
import getpass
if not os.environ.get("GEMINI_API_KEY"):
    os.environ["GEMINI_API_KEY"] = getpass.getpass("GEMINI_API_KEY")
print("API key loaded:","GEMINI_API_KEY" in os.environ)
# Out:
# API key loaded: True

# %%
genai.configure(api_key=os.environ["GEMINI_API_KEY"])

model = genai.GenerativeModel("gemini-flash-latest")

response = model.generate_content("Hello")

print(response.text)
# Out:
# Hello! How can I help you today?

# %%
query = "What is Artificial Intelligence? Explain in simple words."

response = model.generate_content(query)

print(response.text)
# Out:
# In simple words, **Artificial Intelligence (AI)** is when computers or machines are programmed to "think," learn, and make decisions like humans.
#
# Normally, computers can only do what we tell them to do, step-by-step. But with AI, computers can look at information, learn from it, and figure out how to solve problems on their own.
#
# Here is an easy way to understand how it works and how we use it:
#
# ---
#
# ### How does AI learn? (The "Dog" Example)
# Think of how a child learns. If you show a child pictures of dogs, they eventually learn what a dog looks like.
#
# AI works the same way. We show a computer millions of pictures of dogs. At first, it doesn't know what it’s looking at. But after looking at millions of examples, it learns: *"Aha! If it has four legs, fur, and a snout, it’s probably a dog."*
#
# ---
#
# ### AI in Your Everyday Life
# You probably use AI every day without even realizing it:
#
# *   **Netflix and YouTube:** When they recommend a movie or video you might like, AI is guessing your tastes based on what you watched before.
# *   **Siri and Alexa:** When you speak to them, AI translates your voice into code, figures out what you want, and talks back to you.
# *   **Google Maps:** AI looks at traffic data to find the fastest way for you to get home.
# *   **Autocorrect:** When your phone guesses the next word you want to type, that’s AI.
#
# ---
#
# ### The Two Types of AI
# 1.  **Narrow AI (What we have now):** This AI is really good at doing *one* specific job. For example, a chess-playing AI can beat the world champion at chess, but it cannot drive a car or write a recipe.
# 2.  **General AI (The Future / Sci-Fi):** This is a machine that could do any intellectual task a human can do. This does not exist yet—it is only in movies like *Iron Man* (Jarvis) or *Star Wars* (C-3PO).
#
# ### Summary
# AI isn't a magical robot. It is just **very smart software** that learns from experience to make our lives easier.
